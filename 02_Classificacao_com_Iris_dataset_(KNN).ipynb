# %% [markdown]
# # Classificação com KNN - Iris Dataset
# Dataset contendo 3 tipos diferentes de íris (Setosa, Versicolour e Virginica) e 4 features: comprimento e largura de pétalas e sépalas. [Ver imagem](https://www.sobiologia.com.br/conteudos/figuras/Morfofisiologia_vegetal/flor2.jpg).

# %% [markdown]
# ### Alguns Imports

# %%
from sklearn import datasets
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ### Carregando o dataset

# %%
iris = datasets.load_iris()
iris.data[:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %% [markdown]
# ### Treinando e avaliando nosso modelo de classificação de Iris com KNN
#
# **Questão 01**: Avaliar a eficácia de diferentes modelos KNN produzidos com diferentes valores de k. Plotar um gráfico de linha, sendo eixo x os diferentes valores de k e o eixo y os valores de acurácia obtidos na etapa de teste para um determinado modelo.
#
# * Separe dados de treino e teste utilizando o método train_test_split, usando random_state=42 e test_size=0.33.
#
# * Crie um laço com inteiros variando de 1 a 30, onde, em cada iteração, você irá:
# ** Treinar um modelo KNN, utilizando o método fit(), para um valor diferente de k (1, 2, 3, ..., 30).
# ** Gerar valores de predição para o conjunto de teste, utilizando o método predict().
# ** Calcular a acurácia do preditor, utilizando o método accuracy_score().
# ** Acrescentar este resultado ao gráfico.
#
# * Após o laço, plote o gráfico.

# %% [markdown]
# #### Imports

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Separação dos dados de treino e teste

# %%
# Código da separação (split) aqui

X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.33)

# %% [markdown]
# #### Laço com vários ciclos de Treinamento, Teste e Avaliação da Eficácia

# %%
# Código do laço aqui

results = []

for k in range(1, 30): # 0 vizinhos não é válido
  knn_model = KNeighborsClassifier(n_neighbors=k)
  knn_model.fit(X_train, y_train)

  y_pred = knn_model.predict(X_test)

  accuracy = accuracy_score(y_test, y_pred)
  results.append(accuracy)


plt.figure(figsize=(10, 6))
plt.plot(range(1, 30), results, marker='o', linestyle='-', color='red')
plt.xlabel('k (número de vizinhos)')
plt.ylabel('Acurácia')
plt.xticks(range(1, 30))
plt.grid(True)
plt.show()

# %% [markdown]
# Considerando **apenas os resultados deste experimento**, qual valor de K você escolheria? Por quê?

# %% [markdown]
# Resposta: Com base nos resultado deste experimento, um bom valor seria 11 pois é menor resultado que garante um bom desempenho. Vale ressaltar que outros também seriam opções válidas.
